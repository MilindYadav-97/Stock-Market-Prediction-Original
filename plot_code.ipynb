# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Apple

# %%
apple_predictions=pd.read_csv('apple_Predicted_Values.csv')
apple_fastrnn_logs=pd.read_csv('apple_model_history_log_fastrnn.csv')
apple_fastrnn_hybrid_logs=pd.read_csv('apple_model_history_log_fast_hybrid.csv')
apple_lstm_logs=pd.read_csv('apple_model_history_log_lstm.csv')

# %% [markdown]
# ## FB

# %%
fb_predictions=pd.read_csv('fb_Predicted_Values.csv')
fb_fastrnn_logs=pd.read_csv('fb_model_history_log_fastrnn.csv')
fb_fastrnn_hybrid_logs=pd.read_csv('fb_model_history_log_fast_hybrid.csv')
fb_lstm_logs=pd.read_csv('fb_model_history_log_lstm.csv')

# %% [markdown]
# ## Nike

# %%
nike_predictions=pd.read_csv('nike_Predicted_Values.csv')
nike_fastrnn_logs=pd.read_csv('nike_model_history_log_fastrnn.csv')
nike_fastrnn_hybrid_logs=pd.read_csv('nike_model_history_log_fast_hybrid.csv')
nike_lstm_logs=pd.read_csv('nike_model_history_log_lstm.csv')

# %% [markdown]
# ## Uber

# %%
uber_predictions=pd.read_csv('uber_Predicted_Values.csv')
uber_fastrnn_logs=pd.read_csv('uber_model_history_log_fastrnn.csv')
uber_fastrnn_hybrid_logs=pd.read_csv('uber_model_history_log_fast_hybrid.csv')
uber_lstm_logs=pd.read_csv('uber_model_history_log_lstm.csv')

# %% [markdown]
# ## Predicted prices Bar plots

# %%
# apple_predictions.head()

# %%
plt.style.use('fivethirtyeight')
# labels = performance_log_fastrnn['epoch']
apple_test= apple_predictions['Test_Data'][:-30]
apple_FastRNN = apple_predictions['FastRNN'][:-30]
apple_LSTM = apple_predictions['LSTM'][:-30]
apple_FastRNN_hybrid = apple_predictions['FASTRNN_CNN_BiLSTM'][:-30]


fb_test= fb_predictions['Test_Data'][:-30]
fb_FastRNN = fb_predictions['FastRNN'][:-30]
fb_LSTM = fb_predictions['LSTM'][:-30]
fb_FastRNN_hybrid = fb_predictions['FASTRNN_CNN_BiLSTM'][:-30]


nike_test= nike_predictions['Test_Data'][:-30]
nike_FastRNN = nike_predictions['FastRNN'][:-30]
nike_LSTM = nike_predictions['LSTM'][:-30]
nike_FastRNN_hybrid = nike_predictions['FASTRNN_CNN_BiLSTM'][:-30]


uber_test= uber_predictions['Test_Data'][:-30]
uber_FastRNN = uber_predictions['FastRNN'][:-30]
uber_LSTM = uber_predictions['LSTM'][:-30]
uber_FastRNN_hybrid = uber_predictions['FASTRNN_CNN_BiLSTM'][:-30]

# set width of bar
barWidth = 0.18

# %%
r1 = list(np.arange(len(apple_test)))
r2 = [x + barWidth for x in r1]
# r2 = np.array(r2)
r3 = [x + barWidth for x in r2]
# r3 = np.array(r3)
r4 = [x + barWidth for x in r3]

# %%
# plt.figure(figsize=(16, 4))
# fig, ax = plt.subplots(2, 
#            sharex='col', sharey='row')
# sub1 = plt.subplot(1, 2, 1)
# # axes[0]plt.subplots(1,1,figsize=(26,10)) 
# sub1.bar(r1, apple_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
# sub1.bar(r2, apple_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
# sub1.bar(r3, apple_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
# sub1.bar(r4, apple_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

# axes_1 = plt.gca()
# # axes.set_xlim([xmin,xmax])
# sub1.set_ylim([387.2,388.8]) #Change value as per need

# # Add xticks on the middle of the group bars
# sub1.set_title('Apple', fontweight='bold',fontsize=45)
# sub1.set_xlabel('minutes',fontsize=30)
# sub1.set_xticks([r for r in range(0,len(apple_FastRNN))])
# # plt.xticks(len(test))
# sub1.set_ylabel('Closing Price',fontsize=30)
# sub1.legend(loc='upper right',prop={'size': 15})

# %%
# Make the plot
plt.style.use('fivethirtyeight')
fig = plt.subplots( figsize=(40, 20))

############################################################################################################

sub1 = plt.subplot(2, 2, 1)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
sub1.bar(r1, apple_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
sub1.bar(r2, apple_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
sub1.bar(r3, apple_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
sub1.bar(r4, apple_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
sub1.set_ylim([387.2,388.8]) #Change value as per need

# Add xticks on the middle of the group bars
sub1.set_title('Apple', fontweight='bold',fontsize=45)
sub1.set_xlabel('minutes',fontsize=30)
sub1.set_xticks([r for r in range(0,len(apple_FastRNN))])
# plt.xticks(len(test))
sub1.set_ylabel('Closing Price',fontsize=30)
sub1.legend(loc='upper right',prop={'size': 15})
############################################################################################ 2
sub2 = plt.subplot(2, 2, 2)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
sub2.bar(r1, fb_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
sub2.bar(r2, fb_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
sub2.bar(r3, fb_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
sub2.bar(r4, fb_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

# axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
sub2.set_ylim([238.6,239.8]) #Change value as per need

# Add xticks on the middle of the group bars
sub2.set_title('Facebook', fontweight='bold',fontsize=45)
sub2.set_xlabel('minutes',fontsize=30)
sub2.set_xticks([r for r in range(0,len(fb_FastRNN))])
# plt.xticks(len(test))
sub2.set_ylabel('Closing Price',fontsize=30)
sub2.legend(loc='upper right',prop={'size': 15})
######################################################################################## 3
sub3 = plt.subplot(2, 2, 3)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
sub3.bar(r1, nike_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
sub3.bar(r2, nike_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
sub3.bar(r3, nike_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
sub3.bar(r4, nike_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')


# axes.set_xlim([xmin,xmax])
sub3.set_ylim([98.10,98.6]) #Change value as per need

# Add xticks on the middle of the group bars
sub3.set_title('Nike', fontweight='bold',fontsize=45)
sub3.set_xlabel('minutes',fontsize=30)
sub3.set_xticks([r for r in range(0,len(nike_FastRNN))])
# plt.xticks(len(test))
sub3.set_ylabel('Closing Price',fontsize=30)

sub3.legend(loc='upper left',prop={'size': 15})
#######################################################################################################
sub4 = plt.subplot(2, 2, 4)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
sub4.bar(r1, uber_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
sub4.bar(r2, uber_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
sub4.bar(r3, uber_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
sub4.bar(r4, uber_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

# axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
sub4.set_ylim([32.35,32.55]) #Change value as per need

# Add xticks on the middle of the group bars
sub4.set_title('Uber', fontweight='bold',fontsize=45)
sub4.set_xlabel('minutes',fontsize=30)
sub4.set_xticks([r for r in range(0,len(uber_FastRNN))])
# plt.xticks(len(test))
sub4.set_ylabel('Closing Price',fontsize=30)
sub4.legend(loc='upper left',prop={'size': 15})

#########################################################################################
# fig.tight_layout()
plt.show()

# Create legend & Show graphic
# plt_1.legend()

# plt.plot()

# %% [markdown]
# ##4X1 plot

# %%
# Make the plot
plt.style.use('ggplot')
# plt.figure(figsize=(1000, 2000))
# plt.figure(figsize=(300,200))



# plt.subplots( figsize=(40, 20))
fig, ax = plt.subplots(4,figsize=(22,15)) 
############################################################################################################

# sub1 = plt.subplot(1, 2, 1)
# ax[0].subplots(1,1,figsize=(26,10)) 
ax[0].bar(r1, apple_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
ax[0].bar(r2, apple_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
ax[0].bar(r3, apple_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
ax[0].bar(r4, apple_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
ax[0].set_ylim([387.2,388.8]) #Change value as per need
# ax[0].text(3, 389, 'helo')
# Add xticks on the middle of the group bars
ax[0].set_title('Apple',loc='left',fontweight='bold',fontsize=25)
ax[0].set_xlabel('minutes',fontsize=15)
ax[0].set_xticks([r for r in range(0,len(apple_FastRNN))])
# plt.xticks(len(test))
ax[0].set_ylabel('Closing Price',fontsize=15)
ax[0].legend(loc='upper right',prop={'size': 12})
############################################################################################ 2
# sub2 = plt.subplot(2, 2, 2)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
ax[1].bar(r1, fb_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
ax[1].bar(r2, fb_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
ax[1].bar(r3, fb_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
ax[1].bar(r4, fb_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

# axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
ax[1].set_ylim([238.6,239.8]) #Change value as per need

# Add xticks on the middle of the group bars
ax[1].set_title('Facebook',loc='left',fontweight='bold',fontsize=25)
ax[1].set_xlabel('minutes',fontsize=15)
ax[1].set_xticks([r for r in range(0,len(fb_FastRNN))])
# plt.xticks(len(test))
ax[1].set_ylabel('Closing Price',fontsize=15)
ax[1].legend(loc='upper right',prop={'size': 12})
######################################################################################## 3
# sub3 = plt.subplot(2, 2, 3)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
ax[2].bar(r1, nike_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
ax[2].bar(r2, nike_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
ax[2].bar(r3, nike_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
ax[2].bar(r4, nike_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')


# axes.set_xlim([xmin,xmax])
ax[2].set_ylim([98.10,98.6]) #Change value as per need

# Add xticks on the middle of the group bars
ax[2].set_title('Nike',loc='left',fontweight='bold',fontsize=25)
ax[2].set_xlabel('minutes',fontsize=15)
ax[2].set_xticks([r for r in range(0,len(nike_FastRNN))])
# plt.xticks(len(test))
ax[2].set_ylabel('Closing Price',fontsize=15)

ax[2].legend(loc='upper left',prop={'size': 12})
#######################################################################################################
# sub4 = plt.subplot(2, 2, 4)
# axes[0]plt.subplots(1,1,figsize=(26,10)) 
ax[3].bar(r1, uber_test, color='yellow', width=barWidth, edgecolor='black', label='Test_Data')
ax[3].bar(r2, uber_FastRNN, color='navy', width=barWidth, edgecolor='black', label='FastRNN')
ax[3].bar(r3, uber_LSTM, color='red', width=barWidth, edgecolor='black', label='LSTM')
ax[3].bar(r4, uber_FastRNN_hybrid, color='green', width=barWidth, edgecolor='black', label='FASTRNN_CNN_BiLSTM')

# axes_1 = plt.gca()
# axes.set_xlim([xmin,xmax])
ax[3].set_ylim([32.35,32.55]) #Change value as per need

# Add xticks on the middle of the group bars
ax[3].set_title('Uber',loc='left',fontweight='bold',fontsize=25)
ax[3].set_xlabel('minutes',fontsize=15)
ax[3].set_xticks([r for r in range(0,len(uber_FastRNN))])
# plt.xticks(len(test))
ax[3].set_ylabel('Closing Price',fontsize=15)
ax[3].legend(loc='upper left',prop={'size': 12})

#########################################################################################
# fig.tight_layout()
plt.show()

# Create legend & Show graphic
# plt_1.legend()

# plt.plot()

# %% [markdown]
# ## plots for loss

# %%
plt.figure(figsize=(30,20))
plot1 = plt.subplot(2, 2, 1)

# plt.plot(train['Close'], color='green')
 
 
plot1.plot(apple_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
plot1.plot(apple_lstm_logs['loss'],color = 'green',label='LSTM')
plot1.plot(apple_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot1.set_title('Apple',fontweight='bold',fontsize= 45)
plot1.set_xlabel('epochs', fontsize=30)
plot1.set_ylabel("loss", fontsize=30)
 
plot1.legend( loc='upper right',prop={'size': 20})



####################################################################################################
# plt.figure(figsize=(30,20))
plot2 = plt.subplot(2, 2, 2)

# plt.plot(train['Close'], color='green')
 
 
plot2.plot(fb_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
plot2.plot(fb_lstm_logs['loss'],color = 'green',label='LSTM')
plot2.plot(fb_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot2.set_title('Facebook',fontweight='bold',fontsize= 45)
plot2.set_xlabel('epochs', fontsize=30)
plot2.set_ylabel("loss", fontsize=30)
 
plot2.legend( loc='upper right',prop={'size': 20})
######################################################################################################
# plt.figure(figsize=(30,20))
plot3 = plt.subplot(2, 2, 3)

# plt.plot(train['Close'], color='green')
 
 
plot3.plot(nike_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
plot3.plot(nike_lstm_logs['loss'],color = 'green',label='LSTM')
plot3.plot(nike_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot3.set_title('Nike',fontweight='bold',fontsize= 45)
plot3.set_xlabel('epochs', fontsize=30)
plot3.set_ylabel("loss", fontsize=30)
 
plot3.legend( loc='upper right',prop={'size': 20})
##########################################################################################################
# plt.figure(figsize=(30,20))
plot4 = plt.subplot(2, 2, 4)

# plt.plot(train['Close'], color='green')
 
 
plot4.plot(uber_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
plot4.plot(uber_lstm_logs['loss'],color = 'green',label='LSTM')
plot4.plot(uber_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot4.set_title('Uber',fontweight='bold',fontsize= 45)
plot4.set_xlabel('epochs', fontsize=30)
plot4.set_ylabel("loss", fontsize=30)
 
plot4.legend( loc='upper right',prop={'size': 20})
#############################################################################################################
plt.show()

# %% [markdown]
# ##4X1 Plot

# %%
fig, ax = plt.subplots(4,figsize=(17,20)) 

 
ax[0].plot(apple_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
ax[0].plot(apple_lstm_logs['loss'],color = 'green',label='LSTM')
ax[0].plot(apple_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[0].set_title('Apple',fontweight='bold',fontsize= 15)
ax[0].set_xlabel('epochs', fontsize=12)
ax[0].set_ylabel("loss", fontsize=12)
 
ax[0].legend( loc='upper right',prop={'size': 12})



####################################################################################################
# plt.figure(figsize=(30,20))
# plot2 = plt.subplot(2, 2, 2)

# plt.plot(train['Close'], color='green')
 
 
ax[1].plot(fb_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
ax[1].plot(fb_lstm_logs['loss'],color = 'green',label='LSTM')
ax[1].plot(fb_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[1].set_title('Facebook',fontweight='bold',fontsize= 15)
ax[1].set_xlabel('epochs', fontsize=12)
ax[1].set_ylabel("loss", fontsize=12)
 
ax[1].legend( loc='upper right',prop={'size': 12})
######################################################################################################
# plt.figure(figsize=(30,20))
# plot3 = plt.subplot(2, 2, 3)

# plt.plot(train['Close'], color='green')
 
 
ax[2].plot(nike_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
ax[2].plot(nike_lstm_logs['loss'],color = 'green',label='LSTM')
ax[2].plot(nike_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[2].set_title('Nike',fontweight='bold',fontsize= 15)
ax[2].set_xlabel('epochs', fontsize=12)
ax[2].set_ylabel("loss", fontsize=12)
 
ax[2].legend( loc='upper right',prop={'size': 20})
##########################################################################################################
# plt.figure(figsize=(30,20))
# plot4 = plt.subplot(2, 2, 4)

# plt.plot(train['Close'], color='green')
 
 
ax[3].plot(uber_fastrnn_logs['loss'], color= 'navy', label='FastRNN')
ax[3].plot(uber_lstm_logs['loss'],color = 'green',label='LSTM')
ax[3].plot(uber_fastrnn_hybrid_logs['loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[3].set_title('Uber',fontweight='bold',fontsize= 15)
ax[3].set_xlabel('epochs', fontsize=12)
ax[3].set_ylabel("loss", fontsize=12)
 
ax[3].legend( loc='upper right',prop={'size': 20})
#############################################################################################################
plt.show()

# %%
plt.figure(figsize=(30,20))
plot_1 = plt.subplot(2, 2, 1)

# plt.plot(train['Close'], color='green')
 
 
plot_1.plot(apple_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
plot_1.plot(apple_lstm_logs['val_loss'],color = 'green',label='LSTM')
plot_1.plot(apple_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot_1.set_title('Apple',fontweight='bold',fontsize= 45)
plot_1.set_xlabel('epochs', fontsize=30)
plot_1.set_ylabel("val_loss", fontsize=30)
 
plot_1.legend( loc='upper right',prop={'size': 20})



####################################################################################################
# plt.figure(figsize=(30,20))
plot_2 = plt.subplot(2, 2, 2)

# plt.plot(train['Close'], color='green')
 
 
plot_2.plot(fb_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
plot_2.plot(fb_lstm_logs['val_loss'],color = 'green',label='LSTM')
plot_2.plot(fb_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot_2.set_title('Facebook',fontweight='bold',fontsize= 45)
plot_2.set_xlabel('epochs', fontsize=30)
plot_2.set_ylabel("val_loss", fontsize=30)
 
plot_2.legend( loc='upper right',prop={'size': 20})
######################################################################################################
# plt.figure(figsize=(30,20))
plot_3 = plt.subplot(2, 2, 3)

# plt.plot(train['Close'], color='green')
 
 
plot_3.plot(nike_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
plot_3.plot(nike_lstm_logs['val_loss'],color = 'green',label='LSTM')
plot_3.plot(nike_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot_3.set_title('Nike',fontweight='bold',fontsize= 45)
plot_3.set_xlabel('epochs', fontsize=30)
plot_3.set_ylabel("val_loss", fontsize=30)
 
plot_3.legend( loc='upper right',prop={'size': 20})
##########################################################################################################
# plt.figure(figsize=(30,20))
plot_4 = plt.subplot(2, 2, 4)

# plt.plot(train['Close'], color='green')
 
 
plot_4.plot(uber_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
plot_4.plot(uber_lstm_logs['val_loss'],color = 'green',label='LSTM')
plot_4.plot(uber_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

plot_4.set_title('Uber',fontweight='bold',fontsize= 45)
plot_4.set_xlabel('epochs', fontsize=30)
plot_4.set_ylabel("val_loss", fontsize=30)
 
plot_4.legend( loc='upper right',prop={'size': 20})
#############################################################################################################
plt.show()

# %% [markdown]
# ## 4X1

# %%
fig, ax = plt.subplots(4,figsize=(17,20)) 
 
ax[0].plot(apple_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
ax[0].plot(apple_lstm_logs['val_loss'],color = 'green',label='LSTM')
ax[0].plot(apple_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[0].set_title('Apple',fontweight='bold',fontsize= 15)
ax[0].set_xlabel('epochs', fontsize=12)
ax[0].set_ylabel("val_loss", fontsize=12)
 
ax[0].legend( loc='upper right',prop={'size': 20})



####################################################################################################
# plt.figure(figsize=(30,20))
# plot_2 = plt.subplot(2, 2, 2)

# plt.plot(train['Close'], color='green')
 
 
ax[1].plot(fb_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
ax[1].plot(fb_lstm_logs['val_loss'],color = 'green',label='LSTM')
ax[1].plot(fb_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[1].set_title('Facebook',fontweight='bold',fontsize= 15)
ax[1].set_xlabel('epochs', fontsize=12)
ax[1].set_ylabel("val_loss", fontsize=12)
 
ax[1].legend( loc='upper right',prop={'size': 20})
######################################################################################################
# plt.figure(figsize=(30,20))
# plot_3 = plt.subplot(2, 2, 3)

# plt.plot(train['Close'], color='green')
 
 
ax[2].plot(nike_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
ax[2].plot(nike_lstm_logs['val_loss'],color = 'green',label='LSTM')
ax[2].plot(nike_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[2].set_title('Nike',fontweight='bold',fontsize= 15)
ax[2].set_xlabel('epochs', fontsize=12)
ax[2].set_ylabel("val_loss", fontsize=12)
 
ax[2].legend( loc='upper right',prop={'size': 20})
##########################################################################################################
# plt.figure(figsize=(30,20))
# plot_4 = plt.subplot(2, 2, 4)

# plt.plot(train['Close'], color='green')
 
 
ax[3].plot(uber_fastrnn_logs['val_loss'], color= 'navy', label='FastRNN')
ax[3].plot(uber_lstm_logs['val_loss'],color = 'green',label='LSTM')
ax[3].plot(uber_fastrnn_hybrid_logs['val_loss'],color = 'red',label='FASTRNN_CNN_BiLSTM')
# plot1.set_xticks(fontsize=25)
# plot1.set_yticks(fontsize=25)

ax[3].set_title('Uber',fontweight='bold',fontsize= 15)
ax[3].set_xlabel('epochs', fontsize=12)
ax[3].set_ylabel("val_loss", fontsize=12)
 
ax[3].legend( loc='upper right',prop={'size': 20})
#############################################################################################################
plt.show()
